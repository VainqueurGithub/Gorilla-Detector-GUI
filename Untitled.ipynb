# %%
import numpy as np
import pandas as pd

data = pd.read_csv('example.csv', sep = '\t', encoding = 'latin1')
data = data.loc[data['swift']=='ARU02']
data
# Out:
#      Selection           View  Channel  Begin Time (s)  End Time (s)  \
# 101          1  Spectrogram 1        1       11.184014     11.451313
# 102          2  Spectrogram 1        1       12.000000     12.061285
# 103          1  Spectrogram 1        1        6.000000      8.146413
# 104          2  Spectrogram 1        1       15.693803     18.000000
# 105          3  Spectrogram 1        1       21.684133     24.000000
# ..         ...            ...      ...             ...           ...
# 369          2  Spectrogram 1        1       13.730634     13.995644
# 370          3  Spectrogram 1        1       23.837192     23.998490
# 371          4  Spectrogram 1        1       26.172586     26.441720
# 372          5  Spectrogram 1        1       31.450909     31.712141
# 373          6  Spectrogram 1        1       39.288482     39.550531
#
#      Low Freq (Hz)  High Freq (Hz)    label      conf  hour_voc    date_voc  \
# ...
